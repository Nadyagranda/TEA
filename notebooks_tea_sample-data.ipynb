# %%
# Importar pandas

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1, 2, 3]
y = [1, 4, 9]
z = [10, 5, 0]
plt.plot(x, y)
plt.plot(x, z)
plt.title("X & Y Ejemplo")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["este es Y", "este es Z"])
plt.show()

# %%
# Análisis de datos en Python

# %%
sample_data = pd.read_csv("sample_data.csv")

# %%
sample_data
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data.column_c
# Out:
# 0    10
# 1     8
# 2     6
# 3     4
# 4     2
# Name: column_c, dtype: int64

# %%
type(sample_data.column_c)
# Out:
# pandas.core.series.Series

# %%
sample_data.column_c.iloc[3]
# Out:
# 4

# %%
plt.plot(sample_data.column_a, sample_data.column_b)
plt.plot(sample_data.column_a, sample_data.column_c)
plt.show()

# %%
# Analizar el crecimeinto de la población Honduras y Afghanistan

# %%
data = pd.read_csv("countries.csv")

# %%
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
afghanistan = data[data.country == "Afghanistan"]

# %%
afghanistan
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923

# %%
honduras = data[data.country == "Honduras"]

# %%
honduras
# Out:
#       country  year  population
# 648  Honduras  1952     1517453
# 649  Honduras  1957     1770390
# 650  Honduras  1962     2090162
# 651  Honduras  1967     2500689
# 652  Honduras  1972     2965146
# 653  Honduras  1977     3055235
# 654  Honduras  1982     3669448
# 655  Honduras  1987     4372203
# 656  Honduras  1992     5077347
# 657  Honduras  1997     5867957
# 658  Honduras  2002     6677328
# 659  Honduras  2007     7483763

# %%
plt.plot(afghanistan.year, afghanistan.population/10**6)
plt.plot(honduras.year, honduras.population/10**6)
plt.legend(["Afghanistan", "Honduras"])
plt.xlabel("Año")
plt.ylabel("Poblacion (millones)")
plt.show()

# %%
afghanistan.population
# Out:
# 0      8425333
# 1      9240934
# 2     10267083
# 3     11537966
# 4     13079460
# 5     14880372
# 6     12881816
# 7     13867957
# 8     16317921
# 9     22227415
# 10    25268405
# 11    31889923
# Name: population, dtype: int64

# %%
afghanistan.population / afghanistan.population.iloc[0]
# Out:
# 0     1.000000
# 1     1.096803
# 2     1.218597
# 3     1.369437
# 4     1.552397
# 5     1.766146
# 6     1.528939
# 7     1.645983
# 8     1.936769
# 9     2.638165
# 10    2.999099
# 11    3.785004
# Name: population, dtype: float64

# %%
afghanistan.population / afghanistan.population.iloc[0]*100
# Out:
# 0     100.000000
# 1     109.680341
# 2     121.859670
# 3     136.943739
# 4     155.239680
# 5     176.614645
# 6     152.893850
# 7     164.598325
# 8     193.676867
# 9     263.816457
# 10    299.909867
# 11    378.500446
# Name: population, dtype: float64

# %%
plt.plot(afghanistan.year, afghanistan.population / afghanistan.population.iloc[0]*100)
plt.plot(honduras.year, honduras.population / honduras.population.iloc[0]*100)
plt.legend(["Afghanistan", "Honduras"])
plt.xlabel("Año")
plt.ylabel("Crecimiento de la población (1er año 100%)")
plt.show()

# %%
# Expportando los valores de un dataframe a json

# %%
afghanistan.to_json("afghanistan.json")

# %%
honduras.to_json("honduras.json")

# %%
# Leyendo los valores desde json

# %%
afghanistan_desde_archivo = pd.read_json("afghanistan.json")

# %%
afghanistan_desde_archivo
# Out:
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923

# %%
tea_data = pd.read_csv("TEA-Data.csv")

# %%
tea_data
# Out:
#                    Unnamed: 0    Day 1    Day 2    Day 3   Day 4    Day 5  \
# 0         # of Units Produced      700      900    1.000     600      800
# 1                Time (Hours)       24       24       24      24       24
# 2                  Throughput     29.2     37.5     41.7    25.0     33.3
# 3          Cost of Goods Sold  $10.500  $13.500  $15.000  $9.000  $12.000
# 4           Average Inventory      600      600      600     600      600
# 5             Inventory Turns     17.5     22.5     25.0    15.0     20.0
# 6      Raw Materials Per Unit       14       14       14      14       14
# 7              Units Produced      700      900     1000     600      800
# 8   Projected Customer Demand    9.800   12.600   14.000   8.400   11.200
# 9              Scrapped Units       50       50       50      50       50
# 10              Units Prodced      700      900     1000     600      800
# 11                 Scrap Rate     6.7%     5.3%     4.8%    7.7%     5.9%
# ...
